# %%
# 1. LeetCode 225
class MyStack(object):
    def __init__(self):
        self.q1=[]
        self.q2=[]

    def push(self, x):
        self.q2.appqend(x)
        while self.q1:
            self.q2.append(self.ql.pop())
        self.q1,self.q2=self.q2,self.q1

    def pop(self):
        return self.q1.pop(0)

    def top(self):
        return self.q1[0]

    def empty(self):
        return not self.q1
    
# 2. LeetCode 232
class MyQueue(object):

    def __init__(self):
        self.input_stack=[]
        self.output_stack=[]

    def push(self, x):
        self.input_stack.append(x)

    def pop(self):
        if not self.output_stack:
            while self.input_stack:
                self.output_stack.append(self.input_stack.pop())
        return self.output_stack.pop()

    def peek(self):
        self._transfer_if_needed()
        return self.output_stack[-1]
        
    def empty(self):
        return not self.input_stack and not self.output_stack

# 3. Chapter 7. Queue
1. class ListQueue:
    def __init__(self):
        self.__queue=[]

    def enqueue(self,x):
        self.__queue.append(0, x)

    def dequeue(self):
        return self.__queue.pop()

    def front(self):
        return self.__queue[-1]

    def isEmpty(self) ->bool:
        return len(self.__queue)==0

    def dequeueAll(self):
        self.__queue.clear()

2. from collections import deque

def language(s):
    q=deque()

    if '$' not in s:
        return False

    left, right =s.split('$',1)

    for ch in left:
        q.append(ch)

    for ch in right:
        if not q or q.popleft() !=ch:
            return False

    return not q

3. def copyqueue(a):
    b=LinkedQueue()
    temp=LinkedQueue()

    while not a.isEmpty():
        item=a.dequeue()
        b.enqueue(item)
        temp.enqueue(item)

    while not temp.isEmpty():
        a.enqueue(temp.dequeue())

    return b

4. class MyStack(object):
    def __init__(self):
        self.q1=[]
        self.q2=[]

    def push(self, x):
        self.q2.appqend(x)
        while self.q1:
            self.q2.append(self.ql.pop())
        self.q1,self.q2=self.q2,self.q1

    def pop(self):
        return self.q1.pop(0)

5. class MyQueue(object):
    def __init__(self):
        self.input_stack=[]
        self.output_stack=[]

    def enqueue(self, x):
        self.input_stack.append(x)

    def dequeue(self):
        if not self.output_stack:
            while self.input_stack:
                self.output_stack.append(self.input_stack.pop())
        return self.output_stack.pop()

6. 수행시간은 둘다 O(1)이다.

7. enqueue() 수행 시간: O(n), dequeue() 수행 시간: O(1)

8. class ListQueue:
    def __init__(self):
        self.__queue=[]

    def enqueue(self,x):
        self.__queue.append(x)

    def addfront(self,x):
        self.__queue.insert(0,x)

    def dequeue(self):
        if not self.isEmpty():
            return self.__queue.pop(0)
        return None

    def removerear(self):
        if not self.isEmpty():
            return self.__queue.pop()
        return None

    def front(self):
        if self.isEmpty():
            return None
        else:
            return self.__queue[0]

    def rear(self):
        if self.isEmpty():
            return None
        else:
            return self.__queue[-1]

    def isEmpty(self) -> bool:
        return len(self.__queue)==0

    def dequeueAll(self):
        self.__queue.clear()

    def printQueue(self):
        print("Queue from front:", end='')
        for i in range(len(self.__queue)):
            print(self.__queue[i], end='')
        print()
